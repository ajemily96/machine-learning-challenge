# %%
from sklearn import tree
import pandas as pd
import os

from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
X = df[['koi_steff', 'koi_slogg', 'koi_srad']] # 'koi_smet', 'koi_smass', 'koi_sage']]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()


label_encoder.fit(df['koi_disposition'])
label_encoder.classes_
# Out:
# array(['CANDIDATE', 'CONFIRMED', 'FALSE POSITIVE'], dtype=object)

# %%
y_values = label_encoder.transform(df['koi_disposition'])#.astype('int')
y = y_values.reshape(-1, 1)
type(y)
# Out:
# numpy.ndarray

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
X_train.head()
# Out:
#       koi_steff  koi_slogg  koi_srad
# 6122       5737      4.327     1.125
# 6370       5855      4.578     0.797
# 2879       6328      4.481     0.963
# 107        4768      4.536     0.779
# 29         5712      4.359     1.082

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import MinMaxScaler
X_minmax = MinMaxScaler().fit(X_train)
y_minmax = MinMaxScaler().fit(y_train)

X_train_scaled = X_minmax.transform(X_train)
X_test_scaled = X_minmax.transform(X_test)

print(f"Y Shape: {y_train.shape}")
print(f"X Shape: {X_train_scaled.shape}")
# Out:
# Y Shape: (5243, 1)
# X Shape: (5243, 3)

# %% [markdown]
# # Train the Model

# %%
model = RandomForestClassifier(n_estimators=200)
model = model.fit(X_train_scaled, y_train.ravel())
model.score(X_test_scaled, y_test.ravel())
# Out:
# 0.562929061784897

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
model.get_params().keys()
# Out:
# dict_keys(['bootstrap', 'ccp_alpha', 'class_weight', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'max_samples', 'min_impurity_decrease', 'min_impurity_split', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'n_estimators', 'n_jobs', 'oob_score', 'random_state', 'verbose', 'warm_start'])

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {"max_depth": [3, None],
              "max_features": [1, 3, 10],
              "min_samples_split": [3, 10],
              "min_samples_leaf": [3, 10],
              # "bootstrap": [True, False],
              "criterion": ["gini", "entropy"]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
grid.fit(X_train_scaled, y_train.ravel())
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV 1/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=1.0, min_samples_split=1.0; total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=1.0, min_samples_split=1.0; total time=   0.0s
# C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 232, in fit
#     % self.min_samples_leaf)
# ValueError: min_samples_leaf must be at least 1 or in (0, 0.5], got 1.0
#
#   FitFailedWarning)
# C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 232, in fit
#     % self.min_samples_leaf)
# ValueError: min_samples_leaf must be at least 1 or in (0, 0.5], got 1.0
#
#   FitFailedWarning)
# C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 232, in fit
#     % self.min_samples_leaf)
# ValueError: min_samples_leaf must be at least 1 or in (0, 0.5], got 1.0
#
#   FitFailedWarning)
# [CV 3/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=1.0, min_samples_split=1.0; total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=1.0, min_samples_split=1.0; total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=1.0, min_samples_split=1.0; total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=1.0, min_samples_split=3; total time=   0.0s
# C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 232, in fit
#     % self.min_samples_leaf)
# ValueError: min_samples_leaf must be at least 1 or in (0, 0.5], got 1.0
#
#   FitFailedWarning)
# C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 232, in fit
#     % self.min_samples_leaf)
# ValueError: min_samples_leaf must be at least 1 or in (0, 0.5], got 1.0
#
#   FitFailedWarning)
# C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 232, in fit
#     % self.min_samples_leaf)
# ValueError: min_samples_leaf must be at least 1 or in (0, 0.5], got 1.0
#
#   FitFailedWarning)
# C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 232, in fit
#     % self.min_samples_leaf)
# ValueError: min_samples_leaf must be at least 1 or in (0, 0.5], got 1.0
#
#   FitFailedWarning)
# [CV 2/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=1.0, min_samples_split=3; total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=1.0, min_samples_split=3; total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=1.0, min_samples_split=3; total time=   0.0s
# C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 232, in fit
#     % self.min_samples_leaf)
# ValueError: min_samples_leaf must be at least 1 or in (0, 0.5], got 1.0
#
#   FitFailedWarning)
# C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 232, in fit
#     % self.min_samples_leaf)
# ValueError: min_samples_leaf must be at least 1 or in (0, 0.5], got 1.0
#
#   FitFailedWarning)
# C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 232, in fit
#     % self.min_samples_leaf)
# ValueError: min_samples_leaf must be at least 1 or in (0, 0.5], got 1.0
#
#   FitFailedWarning)
# C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 232, in fit
#     % self.min_samples_leaf)
# ValueError: min_samples_leaf must be at least 1 or in (0, 0.5], got 1.0
#
#   FitFailedWarning)
# [CV 5/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=1.0, min_samples_split=3; total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=1.0, min_samples_split=10; total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=1.0, min_samples_split=10; total time=   0.0s
# C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 232, in fit
#     % self.min_samples_leaf)
# ValueError: min_samples_leaf must be at least 1 or in (0, 0.5], got 1.0
#
#   FitFailedWarning)
# C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 232, in fit
#     % self.min_samples_leaf)
# ValueError: min_samples_leaf must be at least 1 or in (0, 0.5], got 1.0
#
#   FitFailedWarning)
# C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 232, in fit
#     % self.min_samples_leaf)
# ValueError: min_samples_leaf must be at least 1 or in (0, 0.5], got 1.0
#
#   FitFailedWarning)
# C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 232, in fit
#     % self.min_samples_leaf)
# ValueError: min_samples_leaf must be at least 1 or in (0, 0.5], got 1.0
#
#   FitFailedWarning)
# [CV 3/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=1.0, min_samples_split=10; total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=1.0, min_samples_split=10; total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=1.0, min_samples_split=10; total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=1.0; total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=1.0; total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=1.0; total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=1.0; total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=1.0; total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3; total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3; total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3; total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3; total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3; total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=10; total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=10; total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=10; total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=10; total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=10; total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=10, min_samples_split=1.0; total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=10, min_samples_split=1.0; total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=10, min_samples_split=1.0; total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=10, min_samples_split=1.0; total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=10, min_samples_split=1.0; total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=10, min_samples_split=3; total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=10, min_samples_split=3; total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=10, min_samples_split=3; total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=10, min_samples_split=3; total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=10, min_samples_split=3; total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=10, min_samples_split=10; total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=10, min_samples_split=10; total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=10, min_samples_split=10; total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=10, min_samples_split=10; total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=1, min_samples_leaf=10, min_samples_split=10; total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=3, min_samples_leaf=1.0, min_samples_split=1.0; total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=3, min_samples_leaf=1.0, min_samples_split=1.0; total time=   0.0s
# C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 232, in fit
#     % self.min_samples_leaf)
# ValueError: min_samples_leaf must be at least 1 or in (0, 0.5], got 1.0
#
#   FitFailedWarning)
# C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 232, in fit
#     % self.min_samples_leaf)
# ValueError: min_samples_leaf must be at least 1 or in (0, 0.5], got 1.0
#
#   FitFailedWarning)
# C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in __call__
# ...
#     result = ImmediateResult(func)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# [CV 4/5] END criterion=entropy, max_depth=None, max_features=10, min_samples_leaf=10, min_samples_split=3; total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, max_features=10, min_samples_leaf=10, min_samples_split=3; total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, max_features=10, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\joblib\parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\brett\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\model_selection\_search.py:921: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan 0.50562659 0.51554534 0.51630833
#  0.50562659 0.51497227 0.51649936        nan        nan        nan
#  0.50562659 0.5250795  0.5250795  0.50562659 0.52374453 0.52355369
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.50562659 0.56494499 0.56418072 0.50562659 0.56570634 0.56723397
#         nan        nan        nan 0.50562659 0.5575066  0.55559803
#  0.50562659 0.56074669 0.5660873         nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.50562659 0.51707151 0.51688085
#  0.50562659 0.51688067 0.51649936        nan        nan        nan
#  0.50562659 0.52336304 0.52488866 0.50562659 0.51897754 0.51993138
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.50562659 0.56818671 0.56475233 0.50562659 0.56799533 0.56742099
#         nan        nan        nan 0.50562659 0.55788701 0.56093844
#  0.50562659 0.5664677  0.56551478        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   category=UserWarning
# [CV 2/5] END criterion=entropy, max_depth=None, max_features=10, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=None, max_features=10, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, max_features=10, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, max_features=10, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# GridSearchCV(estimator=RandomForestClassifier(n_estimators=200),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, None], 'max_features': [1, 3, 10],
#                          'min_samples_leaf': [1.0, 3, 10],
#                          'min_samples_split': [1.0, 3, 10]},
#              verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'criterion': 'entropy', 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.5681867136276644

# %% [markdown]
# # Save the Model

# %%
# import joblib
# filename = 'LogisticRegression.sav'
# joblib.dump(grid, filename)
